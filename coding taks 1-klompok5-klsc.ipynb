# %% [markdown]
#            #Coding Task 1 - Klompok 2 KLS C

# %% [markdown]
# Import Dataset dan Library

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy import stats

# %%
data = pd.read_excel("Dataset.xlsx")
data
# Out:
#      Tanggal  Curah Hujan (mm)  Penjualan A (pcs)  Penjualan B (pcs)
# 0          1               1.4                  0                507
# 1          2               1.2                 27                 61
# 2          3              15.2                458                367
# 3          4              13.4                 20                 21
# 4          5               7.7                  7                  0
# ..       ...               ...                ...                ...
# 116        4               2.2                430                421
# 117        5               0.5                208                 24
# 118        6              33.4                200                189
# 119        7               0.0                  0                324
# 120        8               0.0                143                315
#
# [121 rows x 4 columns]

# %% [markdown]
# Menampilkan Dataset

# %%
# Menghitung statistik
hujan_mean = data['Curah Hujan (mm)'].mean()
mean_a = data['Penjualan A (pcs)'].mean()
mean_b = data['Penjualan B (pcs)'].mean()

hujan_median = data['Curah Hujan (mm)'].median()
median_a = data['Penjualan A (pcs)'].median()
median_b = data['Penjualan B (pcs)'].median()

hujan_modus = data['Curah Hujan (mm)'].mode().iloc[0]
modus_a = data['Penjualan A (pcs)'].mode().iloc[0]
modus_b = data['Penjualan B (pcs)'].mode().iloc[0]

hujan_range = data['Curah Hujan (mm)'].max() - data['Curah Hujan (mm)'].min()
range_a = data['Penjualan A (pcs)'].max() - data['Penjualan A (pcs)'].min()
range_b = data['Penjualan B (pcs)'].max() - data['Penjualan B (pcs)'].min()

IQR_hujan = stats.iqr(data['Curah Hujan (mm)'])
IQR_a = stats.iqr(data['Penjualan A (pcs)'])
IQR_b = stats.iqr(data['Penjualan B (pcs)'])

varian_hujan = data['Curah Hujan (mm)'].var()
varian_a = data['Penjualan A (pcs)'].var()
varian_b = data['Penjualan B (pcs)'].var()

hujan_skew = data['Curah Hujan (mm)'].skew()
skew_a = data['Penjualan A (pcs)'].skew()
skew_b = data['Penjualan B (pcs)'].skew()

hujan_kurtosis = data['Curah Hujan (mm)'].kurtosis()
kurtosis_a = data['Penjualan A (pcs)'].kurtosis()
kurtosis_b = data['Penjualan B (pcs)'].kurtosis()

# Membuat DataFrame langsung tanpa dictionary
df_tampil = pd.DataFrame([
    ['Mean', hujan_mean, mean_a, mean_b],
    ['Median', hujan_median, median_a, median_b],
    ['Modus', hujan_modus, modus_a, modus_b],
    ['Range', hujan_range, range_a, range_b],
    ['IQR', IQR_hujan, IQR_a, IQR_b],
    ['Varians', varian_hujan, varian_a, varian_b],
    ['Skew', hujan_skew, skew_a, skew_b],
    ['Kurtosis', hujan_kurtosis, kurtosis_a, kurtosis_b]
], columns=['Statistik', 'Curah Hujan (mm)', 'Penjualan A (pcs)', 'Penjualan B (pcs)'])

# Menampilkan hasil
print(df_tampil)
# Out:
#   Statistik  Curah Hujan (mm)  Penjualan A (pcs)  Penjualan B (pcs)
# 0      Mean         14.259504         131.834711         205.545455
# 1    Median          2.100000          52.000000         157.000000
# 2     Modus          0.000000           0.000000           0.000000
# 3     Range        170.600000         458.000000         545.000000
# 4       IQR         16.400000         233.000000         244.000000
# 5   Varians        758.465596       20049.672452       25627.250000
# 6      Skew          3.635598           0.708652           0.601558
# 7  Kurtosis         16.575639          -0.856078          -0.815513

# %% [markdown]
# Menampilkan Dataset

# %%
plt.figure(figsize=(15, 10))

# Histogram untuk 'Curah Hujan (mm)'
plt.subplot(3, 1, 1)  # Subplot pertama (3 baris, 1 kolom, plot ke-1)
plt.hist(data['Curah Hujan (mm)'], bins=10, edgecolor='black', alpha=0.7)
plt.axvline(hujan_mean, color='blue', linestyle='dashed', linewidth=2, label=f'Mean: {hujan_mean:.2f}')
plt.axvline(hujan_median, color='red', linestyle='dashed', linewidth=2, label=f'Median: {hujan_median:.2f}')
plt.axvline(hujan_modus, color='green', linestyle='dashed', linewidth=2, label=f'Modus: {hujan_modus:.2f}')
plt.title('Histogram Curah Hujan (mm)')
plt.xlabel('Curah Hujan (mm)')
plt.ylabel('Frekuensi')
plt.legend()

# Histogram untuk 'Penjualan A (pcs)'
plt.subplot(3, 1, 2)  # Subplot kedua
plt.hist(data['Penjualan A (pcs)'], bins=10, edgecolor='black', alpha=0.7)
plt.axvline(mean_a, color='blue', linestyle='dashed', linewidth=2, label=f'Mean: {mean_a:.2f}')
plt.axvline(median_a, color='red', linestyle='dashed', linewidth=2, label=f'Median: {median_a:.2f}')
plt.axvline(modus_a, color='green', linestyle='dashed', linewidth=2, label=f'Modus: {modus_a:.2f}')
plt.title('Histogram Penjualan A (pcs)')
plt.xlabel('Penjualan A (pcs)')
plt.ylabel('Frekuensi')
plt.legend()

# Histogram untuk 'Penjualan B (pcs)'
plt.subplot(3, 1, 3)  # Subplot ketiga
plt.hist(data['Penjualan B (pcs)'], bins=10, edgecolor='black', alpha=0.7)
plt.axvline(mean_b, color='blue', linestyle='dashed', linewidth=2, label=f'Mean: {mean_b:.2f}')
plt.axvline(median_b, color='red', linestyle='dashed', linewidth=2, label=f'Median: {median_b:.2f}')
plt.axvline(modus_b, color='green', linestyle='dashed', linewidth=2, label=f'Modus: {modus_b:.2f}')
plt.title('Histogram Penjualan B (pcs)')
plt.xlabel('Penjualan B (pcs)')
plt.ylabel('Frekuensi')
plt.legend()

plt.tight_layout()  # Untuk mengatur jarak antar plot
plt.show()

# %%
plt.figure(figsize=(20, 18))

plt.subplot(3, 1, 1)
plt.boxplot(data['Curah Hujan (mm)'])
plt.title('Boxplot Curah Hujan (mm)')
plt.ylabel('Curah Hujan (mm)')

plt.subplot(3, 1, 2)
plt.boxplot(data['Penjualan A (pcs)'])
plt.title('Boxplot Penjualan A (pcs)')
plt.ylabel('Penjualan A (pcs)')

plt.subplot(3, 1, 3)
plt.boxplot(data['Penjualan B (pcs)'])
plt.title('Boxplot Penjualan B (pcs)')
plt.ylabel('Penjualan B (pcs)')

plt.tight_layout()
plt.show()

# Deteksi Outlier
def detect_outliers(column):

    Q1 = np.percentile(column, 25)
    Q3 = np.percentile(column, 75)
    # Rentang Interquartile (IQR)
    IQR = Q3 - Q1
    # Batas bawah dan atas untuk mendeteksi outlier
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    # Deteksi outlier
    outliers = column[(column < lower_bound) | (column > upper_bound)]
    return outliers

# Mendeteksi outlier untuk setiap variabel
outliers_hujan = detect_outliers(data['Curah Hujan (mm)'])
outliers_a = detect_outliers(data['Penjualan A (pcs)'])
outliers_b = detect_outliers(data['Penjualan B (pcs)'])

print(f"Outliers Curah Hujan (mm): {outliers_hujan}")
print(f"\nOutliers Penjualan A (pcs): {outliers_a}")
print(f"\nOutliers Penjualan B (pcs): {outliers_b}")
# Out:
# Outliers Curah Hujan (mm): 22      54.5
# 30      55.9
# 38      64.0
# 47      58.0
# 60     100.6
# 76     170.6
# 81      45.5
# 82      68.0
# 85      45.4
# 99     170.6
# 104     45.5
# 105     68.0
# 108     45.4
# Name: Curah Hujan (mm), dtype: float64
#
# Outliers Penjualan A (pcs): Series([], Name: Penjualan A (pcs), dtype: int64)
#
# Outliers Penjualan B (pcs): Series([], Name: Penjualan B (pcs), dtype: int64)

# %%
terdapat dari visualisai data pada boxplot kolom Curah Hujan(mm) terdapat titik - titik 
diatas batas atas

# %%
def detect_outliers(column):
    Q1 = np.percentile(column, 25)
    Q3 = np.percentile(column, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = column[(column < lower_bound) | (column > upper_bound)]
    return outliers

# Mendeteksi outlier untuk setiap variabel
outliers_hujan = detect_outliers(data['Curah Hujan (mm)'])
outliers_a = detect_outliers(data['Penjualan A (pcs)'])
outliers_b = detect_outliers(data['Penjualan B (pcs)'])

# Menghapus outlier dari dataset
data_cleaned = data[~data['Curah Hujan (mm)'].isin(outliers_hujan) &
                     ~data['Penjualan A (pcs)'].isin(outliers_a) &
                     ~data['Penjualan B (pcs)'].isin(outliers_b)]

# Menampilkan boxplot untuk data yang sudah dibersihkan
plt.figure(figsize=(10, 15))

# Boxplot untuk 'Curah Hujan (mm)'
plt.subplot(3, 1, 1)
plt.boxplot(data_cleaned['Curah Hujan (mm)'], vert=True)  # vert=True untuk boxplot vertikal
plt.title('Boxplot Curah Hujan (mm) - Data Bersih')
plt.ylabel('Curah Hujan (mm)')

# Boxplot untuk 'Penjualan A (pcs)'
plt.subplot(3, 1, 2)
plt.boxplot(data_cleaned['Penjualan A (pcs)'], vert=True)  # vert=True untuk boxplot vertikal
plt.title('Boxplot Penjualan A (pcs) - Data Bersih')
plt.ylabel('Penjualan A (pcs)')

# Boxplot untuk 'Penjualan B (pcs)'
plt.subplot(3, 1, 3)
plt.boxplot(data_cleaned['Penjualan B (pcs)'], vert=True)  # vert=True untuk boxplot vertikal
plt.title('Boxplot Penjualan B (pcs) - Data Bersih')
plt.ylabel('Penjualan B (pcs)')

plt.tight_layout()  # Mengatur jarak antar plot
plt.show()

# %% [markdown]
# Kesimpulan
#
# Hasil Analisis Data
#
# 1. Curah Hujan
#    - Persebaran Data: pada data curah hujan, rangenya sangat amat besar.
#    - Outlier: terdapat outlier/nilai ekstrem.
# 2. Penjualan A
#    - Persebaran Data: pada data Penjualan A,terdapat beberapa nilai yang jauh lebih tinggi tetapi nilai nilainya memiliki range dengan angka angka rendah.
#    - Outlier: tidak terdapat outlier
# 3. Penjualan B
#    - Persebaran Data: Pada data Penjualan B, range nilainya cukup stabil dan angka angkanya cenderung lebih tinggi dibanding nilai A.
#    - Outlier: tidak terdapat outlier.
#
# Bentuk Distribusi: Seluruh distribusi cenderung miring ke kiri di karenakan terdapat outlier dengan nilai yang jauh lebih tinggi dari rentan nilai nilai yang ada pada data.
